# %%
subject_name = 'Giada'

from sankar_read_vmrk_events import sankar_read_vmrk_events
import mne
import os
import numpy as np
from mne.io.brainvision import brainvision
import warnings
warnings.filterwarnings('ignore')

data_path = os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd())))

save_path = data_path + '/analysis/python/data/'+subject_name
raw_fname = data_path + '/exp/data/eeg_original/'+subject_name+'.vhdr'

raw = mne.io.read_raw_brainvision(raw_fname,preload=True)
#raw.set_eeg_reference('average', projection=True)  # set EEG average reference
raw.pick_types(meg=False, eeg=True, eog=True, stim=True)

raw.set_channel_types(mapping={'vEOGup': 'eog'})
raw.set_channel_types(mapping={'vEOGdown': 'eog'})
raw.set_channel_types(mapping={'LHEOG': 'eog'})
raw.set_channel_types(mapping={'RHEOG': 'eog'})
raw.rename_channels(mapping={'vEOGup': 'vEOGup'})
raw.rename_channels(mapping={'vEOGdown': 'vEOGdown'})
raw.rename_channels(mapping={'LHEOG': 'LHEOG'})
raw.rename_channels(mapping={'RHEOG': 'RHEOG'})

#events
raw_fname = data_path + '/exp/data/eeg_original/'+subject_name+'.vmrk'
events = sankar_read_vmrk_events(raw_fname)
print(raw.info)
# Out:
# Extracting parameters from D:\projects\current\listen_italian_motor_entrainment/exp/data/eeg_original/Giada.vhdr...
# Setting channel info structure...
# Currently, 1 trigger(s) will be dropped, such as [actiCAP not connected]. Consider using ``event_id`` to parse triggers that do not follow the 'S###' pattern.
# Reading 0 ... 1967699  =      0.000 ...  1967.699 secs...
# Currently, 1 trigger(s) will be dropped, such as [actiCAP not connected]. Consider using ``event_id`` to parse triggers that do not follow the 'S###' pattern.
# <Info | 17 non-empty fields
#     bads : list | 0 items
#     buffer_size_sec : float | 1.0
#     ch_names : list | Fp1, Fp2, F7, F3, Fz, F4, F8, FC5, FC1, ...
#     chs : list | 65 items (EEG: 60, EOG: 4, STIM: 1)
#     comps : list | 0 items
#     custom_ref_applied : bool | False
#     dev_head_t : Transform | 3 items
#     events : list | 0 items
#     highpass : float | 0.015915494309189534 Hz
#     hpi_meas : list | 0 items
#     hpi_results : list | 0 items
#     lowpass : float | 1000.0 Hz
#     meas_date : int | 1525246468
#     nchan : int | 65
#     proc_history : list | 0 items
#     projs : list | 0 items
#     sfreq : float | 1000.0 Hz
#     acq_pars : NoneType
#     acq_stim : NoneType
#     ctf_head_t : NoneType
#     description : NoneType
#     dev_ctf_t : NoneType
#     dig : NoneType
#     experimenter : NoneType
#     file_id : NoneType
#     gantry_angle : NoneType
#     hpi_subsystem : NoneType
#     kit_system_id : NoneType
#     line_freq : NoneType
#     meas_id : NoneType
#     proj_id : NoneType
#     proj_name : NoneType
#     subject_info : NoneType
#     xplotter_layout : NoneType
# >

# %%
# for ferrara brainamp acticap
montage = mne.channels.read_montage('easycap-M1')
ch_names = montage.ch_names
remove_ch = ["Fpz", "Iz","F9", "F10", "P9", "P10", "O9", "O10", "AFz","FT9","FT10","TP9","TP10","PO9","PO10"]
a = np.nonzero(np.in1d(ch_names, remove_ch))[0]
ch_names = np.delete(ch_names,a)
montage = mne.channels.read_montage('easycap-M1',ch_names)
a=raw.set_montage(montage)
# Out:
# The following EEG sensors did not have a position specified in the selected montage: ['RM']. Their position has been left untouched.

# %%
# cut 500 + speech onset - speech offset + 500ms from the original recordings
a=np.where(events[:,2]==5)[0]
b=np.where(events[:,2]==6)[0]
a=np.sort(np.append(a,b))
selected_portion = events[a]

X=500 #500 ms
i=0
a1 =  np.array([(selected_portion[:,0][i]-X),0,100,0])
a2 = np.array([(selected_portion[:,0][i]),0,105,1])
a3 = np.array([(selected_portion[:,0][i+1]),0,106,0])
a4 = np.array([(selected_portion[:,0][i+1]+X),0,200,0])
A = np.vstack((a1,a2,a3,a4))

k=2

for i in range(2, len(selected_portion)-1,2):
    a1 =  np.array([(selected_portion[:,0][i]-X),0,100,0])
    a2 = np.array([(selected_portion[:,0][i]),0,105,k])
    a3 = np.array([(selected_portion[:,0][i+1]),0,106,0])
    a4 = np.array([(selected_portion[:,0][i+1]+X),0,200,0])
    A = np.vstack((A,a1,a2,a3,a4))
    k=k+1
    
selected_portion = A[:,0:3]

# add this events to raw and delete the original one
stim_data = np.zeros((1, len(raw.times)))
info = mne.create_info(['Trigger'], raw.info['sfreq'], ['stim'])
stim_raw = mne.io.RawArray(stim_data, info)

raw.add_channels([stim_raw], force_update_info=True)
raw.add_events(selected_portion, stim_channel='Trigger')
raw.drop_channels(['STI 014'])

info = mne.create_info(['trial_no'], raw.info['sfreq'], ['misc'])
stim_raw = mne.io.RawArray(stim_data, info)
a=A[:,[0, 1, 3]]
raw.add_channels([stim_raw], force_update_info=True)
raw.add_events(a, stim_channel='trial_no')

print(raw.info)
# Out:
# Creating RawArray with float64 data, n_channels=1, n_times=1967700
#     Range : 0 ... 1967699 =      0.000 ...  1967.699 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=1967700
#     Range : 0 ... 1967699 =      0.000 ...  1967.699 secs
# Ready.
# <Info | 18 non-empty fields
#     bads : list | 0 items
#     buffer_size_sec : float | 1.0
#     ch_names : list | Fp1, Fp2, F7, F3, Fz, F4, F8, FC5, FC1, ...
#     chs : list | 66 items (EEG: 60, EOG: 4, STIM: 1, MISC: 1)
#     comps : list | 0 items
#     custom_ref_applied : bool | False
#     dev_head_t : Transform | 3 items
#     dig : list | 236 items
#     events : list | 0 items
#     highpass : float | 0.015915494309189534 Hz
#     hpi_meas : list | 0 items
#     hpi_results : list | 0 items
#     lowpass : float | 1000.0 Hz
#     meas_date : int | 1525246468
#     nchan : int | 66
#     proc_history : list | 0 items
#     projs : list | 0 items
#     sfreq : float | 1000.0 Hz
#     acq_pars : NoneType
#     acq_stim : NoneType
#     ctf_head_t : NoneType
#     description : NoneType
#     dev_ctf_t : NoneType
#     experimenter : NoneType
#     file_id : NoneType
#     gantry_angle : NoneType
#     hpi_subsystem : NoneType
#     kit_system_id : NoneType
#     line_freq : NoneType
#     meas_id : NoneType
#     proj_id : NoneType
#     proj_name : NoneType
#     subject_info : NoneType
#     xplotter_layout : NoneType
# >

# %%
a=mne.find_events(raw)
print(a[:10])
# Out:
# 800 events found
# Event IDs: [100 105 106 200]
# [[20433     0   100]
#  [20933     0   105]
#  [27638     0   106]
#  [28138     0   200]
#  [33143     0   100]
#  [33643     0   105]
#  [38248     0   106]
#  [38748     0   200]
#  [42967     0   100]
#  [43467     0   105]]

# %%
#cut portion of from the original recordings
X = 0.05
raw1 = raw.copy().crop(selected_portion[:,0][0]/1000 - X, selected_portion[:,0][3]/1000 + X)
for i in range(4, len(selected_portion),4):
    raw2 = raw.copy().crop(selected_portion[:,0][i]/1000 - X, selected_portion[:,0][i+3]/1000 + X)
    raw1.append([raw2])
    print(i)
    
event_id = {'Speech_onset': 105,'Speech_offset': 106}
# Out:
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40
# 44
# 48
# 52
# 56
# 60
# 64
# 68
# 72
# 76
# 80
# 84
# 88
# 92
# 96
# 100
# 104
# 108
# 112
# 116
# 120
# 124
# 128
# 132
# 136
# 140
# 144
# 148
# 152
# 156
# 160
# 164
# 168
# 172
# 176
# 180
# 184
# 188
# 192
# 196
# 200
# 204
# 208
# 212
# 216
# 220
# 224
# 228
# 232
# 236
# 240
# 244
# 248
# 252
# 256
# 260
# 264
# 268
# 272
# 276
# 280
# 284
# 288
# 292
# 296
# 300
# 304
# 308
# 312
# 316
# 320
# 324
# 328
# 332
# 336
# 340
# 344
# 348
# 352
# 356
# 360
# 364
# 368
# 372
# 376
# 380
# 384
# 388
# 392
# 396
# 400
# 404
# 408
# 412
# 416
# 420
# 424
# 428
# 432
# 436
# 440
# 444
# 448
# 452
# 456
# 460
# 464
# 468
# 472
# 476
# 480
# 484
# 488
# 492
# 496
# 500
# 504
# 508
# 512
# 516
# 520
# 524
# 528
# 532
# 536
# 540
# 544
# 548
# 552
# 556
# 560
# 564
# 568
# 572
# 576
# 580
# 584
# 588
# 592
# 596
# 600
# 604
# 608
# 612
# 616
# 620
# 624
# 628
# 632
# 636
# 640
# 644
# 648
# 652
# 656
# 660
# 664
# 668
# 672
# 676
# 680
# 684
# 688
# 692
# 696
# 700
# 704
# 708
# 712
# 716
# 720
# 724
# 728
# 732
# 736
# 740
# 744
# 748
# 752
# 756
# 760
# 764
# 768
# 772
# 776
# 780
# 784
# 788
# 792
# 796

# %%
# check and remove the edge boundary annotations and make all of it continues recordings
a=mne.find_events(raw1)
print(a[:10])
raw=raw1
raw.annotations.delete(np.arange(0,raw.annotations.description.shape[0]))
# Out:
# 800 events found
# Event IDs: [100 105 106 200]
# [[20433     0   100]
#  [20933     0   105]
#  [27638     0   106]
#  [28138     0   200]
#  [28239     0   100]
#  [28739     0   105]
#  [33344     0   106]
#  [33844     0   200]
#  [33945     0   100]
#  [34445     0   105]]

# %%
#   Set up pick list: EEG + STI 014 - bad channels (modify to your needs)
include = ['Trigger']  # or stim channels ['STI 014']
raw.info['bads'] = ['RM']  
# pick eeg channels
picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,misc=False,exclude='bads')

# %%
a=raw.plot_psd(picks=picks, tmax=np.inf, fmax=40)
# Out:
# Effective window size : 2.048 (s)

# %%
from mne.preprocessing import ICA
# 1Hz high pass is often helpful for fitting ICA
raw.filter(1., 40., n_jobs=2, fir_design='firwin')
reject = dict(eeg=180e-6)
n_components = 25  # if float, select n_components by explained variance of PCA
method = 'fastica'  # for comparison with EEGLAB try "extended-infomax" here
decim = 3  # we need sufficient statistics, not all time points -> saves time
# we will also set state of the random number generator - ICA is a
# non-deterministic algorithm, but we want to have the same decomposition
# and the same order of components each time this tutorial is run
random_state = 23
ica = ICA(n_components=n_components, method=method, random_state=random_state)
a=ica.fit(raw, picks=picks, decim=decim, reject=reject)
# Out:
# Setting up band-pass filter from 1 - 40 Hz
# l_trans_bandwidth chosen to be 1.0 Hz
# h_trans_bandwidth chosen to be 10.0 Hz
# Filter length of 3301 samples (3.301 sec) selected
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=2)]: Done  60 out of  60 | elapsed:    5.2s finished
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Inferring max_pca_components from picks
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF8']
# Artifact detected in [6003, 6670]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [6670, 7337]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [7337, 8004]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F3', 'Fz', 'F4', 'FC6', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F1', 'F2', 'F6', 'FC4']
# Artifact detected in [9338, 10005]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF4', 'AF8']
# Artifact detected in [10672, 11339]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF8']
# Artifact detected in [16675, 17342]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F3', 'Fz', 'F4', 'F8', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F1', 'F2', 'F6', 'FC4']
# Artifact detected in [22011, 22678]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [23345, 24012]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F1', 'F2', 'F6']
# Artifact detected in [25346, 26013]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [27347, 28014]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F3', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F6']
# Artifact detected in [31349, 32016]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF4', 'AF8']
# Artifact detected in [34684, 35351]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF8']
# Artifact detected in [35351, 36018]
#     Rejecting  epoch based on EEG : ['P7', 'TP8']
# Artifact detected in [39353, 40020]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [44022, 44689]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [44689, 45356]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8', 'F6']
# Artifact detected in [47357, 48024]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [48691, 49358]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [49358, 50025]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [62698, 63365]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [66700, 67367]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [68034, 68701]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'C3', 'Cz', 'C4', 'T8', 'FCz', 'CP1', 'CP2', 'CP6', 'Pz', 'P4', 'P8', 'O2', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F1', 'F2', 'F6', 'FC3', 'FC4', 'FT8', 'C1', 'C2', 'C6', 'CPz', 'CP4', 'TP8', 'P1', 'P2', 'P6', 'POz', 'PO4', 'PO8']
# Artifact detected in [76705, 77372]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [78706, 79373]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [82708, 83375]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [87377, 88044]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [88044, 88711]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF8']
# Artifact detected in [89378, 90045]
#     Rejecting  epoch based on EEG : ['Fp1', 'F3', 'AF7', 'AF8']
# Artifact detected in [92046, 92713]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8', 'F6']
# Artifact detected in [93380, 94047]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F4', 'AF7', 'AF3', 'AF4', 'AF8', 'F6']
# Artifact detected in [94714, 95381]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF4', 'AF8']
# Artifact detected in [96048, 96715]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF8']
# Artifact detected in [106720, 107387]
#     Rejecting  epoch based on EEG : ['P7']
# Artifact detected in [107387, 108054]
#     Rejecting  epoch based on EEG : ['P7']
# Artifact detected in [108054, 108721]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [110055, 110722]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [110722, 111389]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [114057, 114724]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [126063, 126730]
#     Rejecting  epoch based on EEG : ['Fp1']
# Artifact detected in [129398, 130065]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [130065, 130732]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [132066, 132733]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [135401, 136068]
#     Rejecting  epoch based on EEG : ['AF8']
# Artifact detected in [136068, 136735]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [136735, 137402]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'FCz', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'O1', 'Oz', 'O2', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F1', 'F2', 'F6', 'FT7', 'FC3', 'FC4', 'FT8', 'C5', 'C1', 'C2', 'C6', 'TP7', 'CP3', 'CPz', 'CP4', 'TP8', 'P5', 'P1', 'P2', 'P6', 'PO7', 'PO3', 'POz', 'PO4', 'PO8']
# Artifact detected in [140070, 140737]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F4', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F6']
# Artifact detected in [144739, 145406]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F3', 'Fz', 'F4', 'F8', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F1', 'F2', 'F6']
# Artifact detected in [154077, 154744]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [158746, 159413]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [160080, 160747]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF8']
# Artifact detected in [163415, 164082]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [173420, 174087]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [177422, 178089]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F1', 'F2', 'F6']
# Artifact detected in [187427, 188094]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F3', 'F4', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F6']
# Artifact detected in [199433, 200100]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8', 'F6']
# Artifact detected in [204102, 204769]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F4', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F6']
# Artifact detected in [208104, 208771]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF8']
# Artifact detected in [210105, 210772]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [210772, 211439]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [220777, 221444]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [222778, 223445]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F3', 'F4', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F6']
# Artifact detected in [224112, 224779]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F1', 'F2', 'F6']
# Artifact detected in [228114, 228781]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [228781, 229448]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [241454, 242121]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [248124, 248791]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [256795, 257462]
#     Rejecting  epoch based on EEG : ['P7']
# Artifact detected in [272136, 272803]
#     Rejecting  epoch based on EEG : ['FC4']
# Artifact detected in [278806, 279473]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF8']
# Artifact detected in [292813, 293480]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F3', 'F4', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F2', 'F6']
# Artifact detected in [296148, 296815]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'Fz', 'F4', 'F8', 'FC2', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F2', 'F6', 'FC4']
# Artifact detected in [300150, 300817]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [301484, 302151]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [305486, 306153]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [306153, 306820]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [318826, 319493]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F4', 'AF7', 'AF3', 'AF4', 'AF8', 'F6']
# Artifact detected in [320160, 320827]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [324829, 325496]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'F7', 'AF7', 'AF3', 'AF8', 'F5']
# Artifact detected in [325496, 326163]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [329498, 330165]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [334167, 334834]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF8']
# Artifact detected in [339503, 340170]
#     Rejecting  epoch based on EEG : ['P8', 'PO8']
# Artifact detected in [342171, 342838]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF7', 'AF3', 'AF4', 'AF8']
# Artifact detected in [344172, 344839]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2']
# Artifact detected in [347507, 348174]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF8']
# Artifact detected in [357512, 358179]
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2']
# Artifact detected in [362181, 362848]
# Selection by number: 25 components
# Fitting ICA took 21.3s.

# %%
a=ica.plot_components()  # can you spot some potential bad guys?

# %%
# %matplotlib inline
eog_inds =[0]
a=ica.plot_properties(raw, picks=eog_inds,psd_args={'fmax': 35.})
# Out:
#     using multitaper spectrum estimation with 7 DPSS windows

# %%
#picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=True,include=include, exclude='bads')
#eog_average = create_eog_epochs(raw, reject=reject,picks=picks).average()
#ica.plot_overlay(eog_average, exclude=eog_inds, show=False)
# red -> before, black -> after. Yes! We remove quite a lot!

# to definitely register this component as a bad one to be removed
# there is the ``ica.exclude`` attribute, a simple Python list
ica.exclude.extend(eog_inds)

# from now on the ICA will reject this component even if no exclude
# parameter is passed, and this information will be stored to disk
# on saving

# uncomment this for reading and writing
ica.save(save_path +'-ica.fif')
# ica = read_ica('my-ica.fif')
# Out:
# Writing ICA solution to D:\projects\current\listen_italian_motor_entrainment/analysis/python/data/Giada-ica.fif...
# <ICA  |  raw data decomposition, fit (fastica): 305486 samples, 25 components, channels used: "eeg", 1 sources marked for exclusion>

# %%
ica.apply(raw)
a=raw.plot()  # check the result
# Out:
# Transforming to ICA space (25 components)
# Zeroing out 1 ICA components

# %%
picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=True, eog=False, misc=True,exclude='bads')
raw.save(save_path +'_raw.fif',picks=picks,overwrite=True)
# Out:
# Writing D:\projects\current\listen_italian_motor_entrainment\analysis\python\data\Giada_raw.fif
# Closing D:\projects\current\listen_italian_motor_entrainment\analysis\python\data\Giada_raw.fif [done]
